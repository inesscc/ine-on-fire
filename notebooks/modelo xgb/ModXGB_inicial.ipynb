# %%
import pandas as pd
from pycaret.classification import *

#from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize

import xgboost as xgb
import shap
import numpy as np
from xgboost import plot_importance

# %% [markdown]
# Load data

# %%
data_consolidada = pd.read_csv('data_consolidados_sentinel2_distancias_indices_era5.csv')
data_consolidada.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        time  dim_0  coastal    blue   green  \
# 0             0           0  2022-02-02      0   0.1324  0.1278  0.1418
# 1             1           1  2022-02-02      1   0.1313  0.1252  0.1425
# 2             2           2  2022-02-02      2   0.1388  0.1322  0.1465
# 3             3           3  2022-02-02      3   0.1325  0.1284  0.1394
# 4             4           4  2022-02-02      4   0.1350  0.1376  0.1542
#
#       red   nir08  swir16  ...  total_precipitation_sum  \
# 0  0.1498  0.2619  0.2929  ...             2.682209e-07
# 1  0.1383  0.2820  0.2676  ...             2.682209e-07
# 2  0.1517  0.2457  0.2914  ...             2.682209e-07
# 3  0.1420  0.2357  0.2532  ...             2.682209e-07
# 4  0.1680  0.2580  0.3237  ...             2.682209e-07
#
#    u_component_of_wind_10m  u_component_of_wind_10m_max  \
# 0                 1.796789                     4.297897
# 1                 1.796789                     4.297897
# 2                 1.796789                     4.297897
# 3                 1.796789                     4.297897
# 4                 1.796789                     4.297897
#
#    u_component_of_wind_10m_min  v_component_of_wind_10m  \
# 0                    -0.679688                -0.072233
# 1                    -0.679688                -0.072233
# 2                    -0.679688                -0.072233
# 3                    -0.679688                -0.072233
# 4                    -0.679688                -0.072233
#
#   v_component_of_wind_10m_max v_component_of_wind_10m_min  \
# 0                    0.688393                   -0.924824
# 1                    0.688393                   -0.924824
# 2                    0.688393                   -0.924824
# 3                    0.688393                   -0.924824
# 4                    0.688393                   -0.924824
#
#   volumetric_soil_water_layer_1 volumetric_soil_water_layer_1_max  \
# 0                      0.249864                          0.249893
# 1                      0.249864                          0.249893
# 2                      0.249864                          0.249893
# 3                      0.249864                          0.249893
# 4                      0.249864                          0.249893
#
#   volumetric_soil_water_layer_1_min
# 0                          0.249817
# 1                          0.249817
# 2                          0.249817
# 3                          0.249817
# 4                          0.249817
#
# [5 rows x 61 columns]

# %%
data_consolidada.shape
# Out:
# (202264, 61)

# %% [markdown]
# #### Procesamiento input modelo

# %%
# eliminamos columnas que no nos son de interes para el modelo
aux = data_consolidada.drop(['nom_incen','causa', 'provincia', 'comuna', 'codreg', 'codprov', 'codcom', 'superficie',
                             'coastal', 'blue', 'green', 'red', 'nir08', 'swir16',	'swir22',
                             'spatial_ref', 'temporada', 'region', 'fecha_ter', 'Unnamed: 0', 'Unnamed: 0.1', 'dim_0', 'geometry',
                             'dewpoint_temperature_2m_min', 'soil_temperature_level_1', 'v_component_of_wind_10m_min', 'temperature_2m_max',
                             'volumetric_soil_water_layer_1_max', 'temperature_2m_min', 'soil_temperature_level_1_min', 'd_areas_urbanas', 'd_red_hidrografica',
                             'total_precipitation_max', 'temperature_2m', 'total_precipitation_min'], axis= 1)
aux
# Out:
#               time          y         x  es_incendio   id_incendio  \
# 0       2022-02-02  6265890.0  269650.0            0   2021-2022-3
# 1       2022-02-02  6264130.0  269930.0            1   2021-2022-3
# 2       2022-02-02  6263950.0  268650.0            0   2021-2022-3
# 3       2022-02-02  6264110.0  271090.0            0   2021-2022-3
# 4       2022-02-02  6263770.0  267790.0            0   2021-2022-3
# ...            ...        ...       ...          ...           ...
# 202259  2020-12-19  6413410.0  337370.0            0  2020-2021-11
# 202260  2020-12-19  6414050.0  355550.0            0  2020-2021-11
# 202261  2020-12-19  6418430.0  299270.0            0  2020-2021-11
# 202262  2020-12-19  6438610.0  291270.0            0  2020-2021-11
# 202263  2020-12-19  6425270.0  323530.0            0  2020-2021-11
#
#          fecha_ini      tipo_dato  id_pixel   id_pixel_incendio  \
# 0       2022-02-23  zona_incendio         1       2021-2022-3-1
# 1       2022-02-23  zona_incendio         2       2021-2022-3-2
# 2       2022-02-23  zona_incendio         3       2021-2022-3-3
# 3       2022-02-23  zona_incendio         4       2021-2022-3-4
# 4       2022-02-23  zona_incendio         5       2021-2022-3-5
# ...            ...            ...       ...                 ...
# 202259  2020-12-15    zona_random     53339  2020-2021-11-53339
# 202260  2020-12-15    zona_random     53340  2020-2021-11-53340
# 202261  2020-12-15    zona_random     53341  2020-2021-11-53341
# 202262  2020-12-15    zona_random     53342  2020-2021-11-53342
# 202263  2020-12-15    zona_random     53343  2020-2021-11-53343
#
#         d_areas_silvestres_protegidas  ...  dewpoint_temperature_2m_max  \
# 0                        17016.080381  ...                   286.620651
# 1                        16811.721774  ...                   286.620651
# 2                        15523.777524  ...                   286.620651
# 3                        17941.154099  ...                   286.620651
# 4                        14645.361310  ...                   286.620651
# ...                               ...  ...                          ...
# 202259                   65288.415231  ...                          NaN
# 202260                   75389.173713  ...                          NaN
# 202261                   39807.426376  ...                          NaN
# 202262                   51400.147186  ...                          NaN
# 202263                   63460.355144  ...                          NaN
#
#         soil_temperature_level_1_max  total_precipitation_sum  \
# 0                         305.639877             2.682209e-07
# 1                         305.639877             2.682209e-07
# 2                         305.639877             2.682209e-07
# 3                         305.639877             2.682209e-07
# 4                         305.639877             2.682209e-07
# ...                              ...                      ...
# 202259                           NaN                      NaN
# 202260                           NaN                      NaN
# 202261                           NaN                      NaN
# 202262                           NaN                      NaN
# 202263                           NaN                      NaN
#
#         u_component_of_wind_10m u_component_of_wind_10m_max  \
# 0                      1.796789                    4.297897
# 1                      1.796789                    4.297897
# 2                      1.796789                    4.297897
# 3                      1.796789                    4.297897
# 4                      1.796789                    4.297897
# ...                         ...                         ...
# 202259                      NaN                         NaN
# 202260                      NaN                         NaN
# 202261                      NaN                         NaN
# 202262                      NaN                         NaN
# 202263                      NaN                         NaN
#
#         u_component_of_wind_10m_min  v_component_of_wind_10m  \
# 0                         -0.679688                -0.072233
# 1                         -0.679688                -0.072233
# 2                         -0.679688                -0.072233
# 3                         -0.679688                -0.072233
# 4                         -0.679688                -0.072233
# ...                             ...                      ...
# 202259                          NaN                      NaN
# 202260                          NaN                      NaN
# 202261                          NaN                      NaN
# 202262                          NaN                      NaN
# 202263                          NaN                      NaN
#
#         v_component_of_wind_10m_max  volumetric_soil_water_layer_1  \
# 0                          0.688393                       0.249864
# 1                          0.688393                       0.249864
# 2                          0.688393                       0.249864
# 3                          0.688393                       0.249864
# 4                          0.688393                       0.249864
# ...                             ...                            ...
# 202259                          NaN                            NaN
# 202260                          NaN                            NaN
# 202261                          NaN                            NaN
# 202262                          NaN                            NaN
# 202263                          NaN                            NaN
#
#         volumetric_soil_water_layer_1_min
# 0                                0.249817
# 1                                0.249817
# 2                                0.249817
# 3                                0.249817
# 4                                0.249817
# ...                                   ...
# 202259                                NaN
# 202260                                NaN
# 202261                                NaN
# 202262                                NaN
# 202263                                NaN
#
# [202264 rows x 26 columns]

# %% [markdown]
# Filtramos pixeles que posean al menos un historial de 3 imagenes recolectadas:

# %%
n_id= aux['id_pixel_incendio'].value_counts()
aux = aux.merge(n_id, how = 'left', on = 'id_pixel_incendio')
aux = aux[ aux['count']>=3].drop('count', axis =1)
aux.shape
# Out:
# (179985, 26)

# %% [markdown]
# Filtramos fechas de captura según el inicio del incendio. Nos quedaremos solo con la información del estado previo al incendio, es decir, si el tiempo de captura es menor o igual al inicio del incendio.

# %%
# transformamos a fecha
aux['fecha_ini'] = pd.to_datetime(aux['fecha_ini'])
aux['time'] = pd.to_datetime(aux['time'])

# Filtrar las fechas actuales que son anteriores a la fecha de inicio
filtro = aux['time'] <= aux['fecha_ini']
fechas_antiguas = aux[filtro]

# Quedarse con la fecha actual más cercana a la fecha de inicio
fechas_antiguas['Diferencia'] = (fechas_antiguas['time'] - fechas_antiguas['fecha_ini']).abs()

# %% [markdown]
# Puesto que hay imagenes que poseen problemas en la captura y producen valores faltantes en el dataset, se realizó una imputación según el valor anterior capturado tal como se muestra a continuación:

# %%
fechas_antiguas_interp = fechas_antiguas.sort_values(by= ['id_pixel_incendio', 'time']).groupby('id_pixel_incendio').apply(lambda group: group.interpolate(method= 'pad')).reset_index(drop= True)

# %%
# Ejemplo
print(fechas_antiguas[fechas_antiguas['id_pixel']==17])

fechas_antiguas_interp[fechas_antiguas_interp['id_pixel']==17]
# Out:
#            time          y         x  es_incendio  id_incendio  fecha_ini  \
# 16   2022-02-02  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 2228 2022-02-07  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 4440 2022-02-12  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 6652 2022-02-17  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 8864 2022-02-22  6265870.0  270830.0            0  2021-2022-3 2022-02-23
#
#           tipo_dato  id_pixel id_pixel_incendio  \
# 16    zona_incendio        17    2021-2022-3-17
# 2228  zona_incendio        17    2021-2022-3-17
# 4440  zona_incendio        17    2021-2022-3-17
# 6652  zona_incendio        17    2021-2022-3-17
# 8864  zona_incendio        17    2021-2022-3-17
#
#       d_areas_silvestres_protegidas  ...  soil_temperature_level_1_max  \
# 16                       18132.9481  ...                    305.639877
# 2228                     18132.9481  ...                    305.399445
# 4440                     18132.9481  ...                    306.026138
# 6652                     18132.9481  ...                    306.975418
# 8864                     18132.9481  ...                    303.765381
#
#       total_precipitation_sum  u_component_of_wind_10m  \
# 16               2.682209e-07                 1.796789
# 2228             4.127032e-05                 1.525106
# 4440             0.000000e+00                 1.252339
# 6652             0.000000e+00                 1.613927
# 8864             1.724633e-06                 1.014877
#
#       u_component_of_wind_10m_max u_component_of_wind_10m_min  \
# 16                       4.297897                   -0.679688
# 2228                     3.959015                    0.018539
# 4440                     3.305115                   -0.384216
# 6652                     4.945160                   -0.743942
# 8864                     3.723633                   -0.954651
#
#       v_component_of_wind_10m  v_component_of_wind_10m_max  \
# 16                  -0.072233                     0.688393
# 2228                -0.785921                     0.216309
# 4440                -1.294714                     0.122762
# 6652                 0.581790                     0.936739
# 8864                -1.251980                    -0.272659
#
#       volumetric_soil_water_layer_1  volumetric_soil_water_layer_1_min  \
# 16                         0.249864                           0.249817
# 2228                       0.250044                           0.249847
# 4440                       0.250001                           0.249939
# 6652                       0.249907                           0.249832
# 8864                       0.249769                           0.249741
#
#       Diferencia
# 16       21 days
# 2228     16 days
# 4440     11 days
# 6652      6 days
# 8864      1 days
#
# [5 rows x 27 columns]
#             time          y         x  es_incendio  id_incendio  fecha_ini  \
# 70542 2022-02-02  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 70543 2022-02-07  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 70544 2022-02-12  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 70545 2022-02-17  6265870.0  270830.0            0  2021-2022-3 2022-02-23
# 70546 2022-02-22  6265870.0  270830.0            0  2021-2022-3 2022-02-23
#
#            tipo_dato  id_pixel id_pixel_incendio  \
# 70542  zona_incendio        17    2021-2022-3-17
# 70543  zona_incendio        17    2021-2022-3-17
# 70544  zona_incendio        17    2021-2022-3-17
# 70545  zona_incendio        17    2021-2022-3-17
# 70546  zona_incendio        17    2021-2022-3-17
#
#        d_areas_silvestres_protegidas  ...  soil_temperature_level_1_max  \
# 70542                     18132.9481  ...                    305.639877
# 70543                     18132.9481  ...                    305.399445
# 70544                     18132.9481  ...                    306.026138
# 70545                     18132.9481  ...                    306.975418
# 70546                     18132.9481  ...                    303.765381
#
#        total_precipitation_sum  u_component_of_wind_10m  \
# 70542             2.682209e-07                 1.796789
# 70543             4.127032e-05                 1.525106
# 70544             0.000000e+00                 1.252339
# 70545             0.000000e+00                 1.613927
# 70546             1.724633e-06                 1.014877
#
#        u_component_of_wind_10m_max u_component_of_wind_10m_min  \
# 70542                     4.297897                   -0.679688
# 70543                     3.959015                    0.018539
# 70544                     3.305115                   -0.384216
# 70545                     4.945160                   -0.743942
# 70546                     3.723633                   -0.954651
#
#        v_component_of_wind_10m  v_component_of_wind_10m_max  \
# 70542                -0.072233                     0.688393
# 70543                -0.785921                     0.216309
# 70544                -1.294714                     0.122762
# 70545                 0.581790                     0.936739
# 70546                -1.251980                    -0.272659
#
#        volumetric_soil_water_layer_1  volumetric_soil_water_layer_1_min  \
# 70542                       0.249864                           0.249817
# 70543                       0.250044                           0.249847
# 70544                       0.250001                           0.249939
# 70545                       0.249907                           0.249832
# 70546                       0.249769                           0.249741
#
#        Diferencia
# 70542     21 days
# 70543     16 days
# 70544     11 days
# 70545      6 days
# 70546      1 days
#
# [5 rows x 27 columns]

# %% [markdown]
# Una vez interpolado los valores faltantes, pasamos a la siguiente etapa: dejar la información a nivel de pixel, en donde identificamos los valores más cercanos antes del incendio y realizamos un promedio a nivel de pixel-incendio para los demas datos, obteniendo columnas con la situación actual y otras con el historial previo:

# %%
idx = fechas_antiguas_interp.groupby(['id_pixel_incendio'])['Diferencia'].idxmin()
fecha_cercana = fechas_antiguas_interp.loc[idx].drop(['time2'], axis = 1)

# %% [markdown]
# Calculamos el promedio:

# %%
fechas_antiguas_resum = fechas_antiguas_interp.drop(['time', 'y', 'x', 'es_incendio', 'fecha_ini', 'Diferencia', 'tipo_dato', 'id_pixel','id_incendio', 'time2',
                                                     'd_areas_silvestres_protegidas','d_red_vial'], axis =1)                 # eliminamos de distancias pues es el mismo pixel
ind_fechas_antiguas = fechas_antiguas_interp[['y', 'x', 'es_incendio', 'id_incendio', 'id_pixel']].drop_duplicates()

promedio = fechas_antiguas_resum.groupby(['id_pixel_incendio']).mean()
promedio
# Out:
#                          ndvi       evi      ndwi  dewpoint_temperature_2m  \
# id_pixel_incendio
# 2016-2017-104-13275  0.747302  0.313434  0.172112               282.174499
# 2016-2017-104-2083   0.836314  0.253355  0.246712               284.268818
# 2016-2017-104-2283   0.163585  0.099741 -0.087652               284.268818
# 2016-2017-104-2314   0.695956  0.306123  0.213982               284.268818
# 2016-2017-104-2784   0.706291  0.255024  0.160011               284.268818
# ...                       ...       ...       ...                      ...
# 2022-2023-4-49542    0.034575  0.018420  0.099872                      NaN
# 2022-2023-4-49543    0.232758  0.139127 -0.073352                      NaN
# 2022-2023-4-49544    0.226516  0.179758 -0.068663                      NaN
# 2022-2023-4-49545    0.121194  0.091991 -0.123287                      NaN
# 2022-2023-4-49546    0.183209  0.113955 -0.026158                      NaN
#
#                      dewpoint_temperature_2m_max  \
# id_pixel_incendio
# 2016-2017-104-13275                   284.911077
# 2016-2017-104-2083                    285.841258
# 2016-2017-104-2283                    285.841258
# 2016-2017-104-2314                    285.841258
# 2016-2017-104-2784                    285.841258
# ...                                          ...
# 2022-2023-4-49542                            NaN
# 2022-2023-4-49543                            NaN
# 2022-2023-4-49544                            NaN
# 2022-2023-4-49545                            NaN
# 2022-2023-4-49546                            NaN
#
#                      soil_temperature_level_1_max  total_precipitation_sum  \
# id_pixel_incendio
# 2016-2017-104-13275                    308.723872                 0.000120
# 2016-2017-104-2083                     304.751867                 0.000001
# 2016-2017-104-2283                     304.751867                 0.000001
# 2016-2017-104-2314                     304.751867                 0.000001
# 2016-2017-104-2784                     304.751867                 0.000001
# ...                                           ...                      ...
# 2022-2023-4-49542                             NaN                      NaN
# 2022-2023-4-49543                             NaN                      NaN
# 2022-2023-4-49544                             NaN                      NaN
# 2022-2023-4-49545                             NaN                      NaN
# 2022-2023-4-49546                             NaN                      NaN
#
#                      u_component_of_wind_10m  u_component_of_wind_10m_max  \
# id_pixel_incendio
# 2016-2017-104-13275                 0.638061                     2.318019
# 2016-2017-104-2083                  1.519517                     4.073023
# 2016-2017-104-2283                  1.519517                     4.073023
# 2016-2017-104-2314                  1.519517                     4.073023
# 2016-2017-104-2784                  1.519517                     4.073023
# ...                                      ...                          ...
# 2022-2023-4-49542                        NaN                          NaN
# 2022-2023-4-49543                        NaN                          NaN
# 2022-2023-4-49544                        NaN                          NaN
# 2022-2023-4-49545                        NaN                          NaN
# 2022-2023-4-49546                        NaN                          NaN
#
#                      u_component_of_wind_10m_min  v_component_of_wind_10m  \
# id_pixel_incendio
# 2016-2017-104-13275                    -1.062608                 0.103451
# 2016-2017-104-2083                     -0.401321                 3.248165
# 2016-2017-104-2283                     -0.401321                 3.248165
# 2016-2017-104-2314                     -0.401321                 3.248165
# 2016-2017-104-2784                     -0.401321                 3.248165
# ...                                          ...                      ...
# 2022-2023-4-49542                            NaN                      NaN
# 2022-2023-4-49543                            NaN                      NaN
# 2022-2023-4-49544                            NaN                      NaN
# 2022-2023-4-49545                            NaN                      NaN
# 2022-2023-4-49546                            NaN                      NaN
#
#                      v_component_of_wind_10m_max  \
# id_pixel_incendio
# 2016-2017-104-13275                     0.839816
# 2016-2017-104-2083                      4.650551
# 2016-2017-104-2283                      4.650551
# 2016-2017-104-2314                      4.650551
# 2016-2017-104-2784                      4.650551
# ...                                          ...
# 2022-2023-4-49542                            NaN
# 2022-2023-4-49543                            NaN
# 2022-2023-4-49544                            NaN
# 2022-2023-4-49545                            NaN
# 2022-2023-4-49546                            NaN
#
#                      volumetric_soil_water_layer_1  \
# id_pixel_incendio
# 2016-2017-104-13275                       0.146767
# 2016-2017-104-2083                        0.176087
# 2016-2017-104-2283                        0.176087
# 2016-2017-104-2314                        0.176087
# 2016-2017-104-2784                        0.176087
# ...                                            ...
# 2022-2023-4-49542                              NaN
# 2022-2023-4-49543                              NaN
# 2022-2023-4-49544                              NaN
# 2022-2023-4-49545                              NaN
# 2022-2023-4-49546                              NaN
#
#                      volumetric_soil_water_layer_1_min
# id_pixel_incendio
# 2016-2017-104-13275                           0.138229
# 2016-2017-104-2083                            0.175908
# 2016-2017-104-2283                            0.175908
# 2016-2017-104-2314                            0.175908
# 2016-2017-104-2784                            0.175908
# ...                                                ...
# 2022-2023-4-49542                                  NaN
# 2022-2023-4-49543                                  NaN
# 2022-2023-4-49544                                  NaN
# 2022-2023-4-49545                                  NaN
# 2022-2023-4-49546                                  NaN
#
# [35662 rows x 14 columns]

# %%
df_cols = fecha_cercana.merge(promedio, how = 'left', on = ['id_pixel_incendio'], suffixes=['_t', '_tmean'])
df_cols = df_cols.drop(['Diferencia'], axis =1)
df_proc = df_cols

# %% [markdown]
# Revisamos valores faltantes nuevamente:

# %%
df_proc.isna().sum()
# Out:
# time                                         0
# y                                            0
# x                                            0
# es_incendio                                  0
# id_incendio                                  0
# fecha_ini                                    0
# tipo_dato                                    0
# id_pixel                                     0
# id_pixel_incendio                            0
# d_areas_silvestres_protegidas                0
# d_red_vial                                   0
# ndvi_t                                      56
# evi_t                                       57
# ndwi_t                                      55
# dewpoint_temperature_2m_t                  742
# dewpoint_temperature_2m_max_t              742
# soil_temperature_level_1_max_t             742
# total_precipitation_sum_t                  742
# u_component_of_wind_10m_t                  742
# u_component_of_wind_10m_max_t              742
# u_component_of_wind_10m_min_t              742
# v_component_of_wind_10m_t                  742
# v_component_of_wind_10m_max_t              742
# volumetric_soil_water_layer_1_t            742
# volumetric_soil_water_layer_1_min_t        742
# ndvi_tmean                                  56
# evi_tmean                                   57
# ndwi_tmean                                  55
# dewpoint_temperature_2m_tmean              742
# dewpoint_temperature_2m_max_tmean          742
# soil_temperature_level_1_max_tmean         742
# total_precipitation_sum_tmean              742
# u_component_of_wind_10m_tmean              742
# u_component_of_wind_10m_max_tmean          742
# u_component_of_wind_10m_min_tmean          742
# v_component_of_wind_10m_tmean              742
# v_component_of_wind_10m_max_tmean          742
# volumetric_soil_water_layer_1_tmean        742
# volumetric_soil_water_layer_1_min_tmean    742
# dtype: int64

# %% [markdown]
# Al realizar la imputación de valores faltantes dependemos de los demás valores existentes, en el caso de que no exista información, eliminaremos el pixel.

# %%
# Ejemplo:
fechas_antiguas_interp[fechas_antiguas_interp['id_pixel']== 24720]  # a
# Out:
#             time          y         x  es_incendio  id_incendio  fecha_ini  \
# 85390 2021-07-02  6370590.0  381430.0            0  2021-2022-4 2021-07-25
# 85391 2021-07-07  6370590.0  381430.0            0  2021-2022-4 2021-07-25
# 85392 2021-07-17  6370590.0  381430.0            0  2021-2022-4 2021-07-25
# 85393 2021-07-22  6370590.0  381430.0            0  2021-2022-4 2021-07-25
#
#          tipo_dato  id_pixel  id_pixel_incendio  \
# 85390  zona_random     24720  2021-2022-4-24720
# 85391  zona_random     24720  2021-2022-4-24720
# 85392  zona_random     24720  2021-2022-4-24720
# 85393  zona_random     24720  2021-2022-4-24720
#
#        d_areas_silvestres_protegidas  ...  soil_temperature_level_1_max  \
# 85390                   71447.954596  ...                    272.854385
# 85391                   71447.954596  ...                    272.637772
# 85392                   71447.954596  ...                    272.084610
# 85393                   71447.954596  ...                    271.999542
#
#        total_precipitation_sum  u_component_of_wind_10m  \
# 85390             2.926588e-05                -1.449002
# 85391             3.615022e-06                -1.648202
# 85392             8.523463e-07                -1.992614
# 85393             0.000000e+00                -1.646520
#
#        u_component_of_wind_10m_max u_component_of_wind_10m_min  \
# 85390                    -0.548264                   -2.263870
# 85391                    -0.712418                   -2.509979
# 85392                    -1.335205                   -2.422699
# 85393                    -0.587463                   -2.217499
#
#        v_component_of_wind_10m  v_component_of_wind_10m_max  \
# 85390                 0.011151                     0.249710
# 85391                 0.021126                     0.113708
# 85392                 0.018242                     0.075043
# 85393                -0.061281                     0.022629
#
#        volumetric_soil_water_layer_1  volumetric_soil_water_layer_1_min  \
# 85390                       0.207290                           0.207275
# 85391                       0.207205                           0.207199
# 85392                       0.207745                           0.207703
# 85393                       0.223948                           0.220612
#
#        Diferencia
# 85390     23 days
# 85391     18 days
# 85392      8 days
# 85393      3 days
#
# [4 rows x 27 columns]

# %%
df_proc = df_proc.dropna()  # eliminando

# %%
df_proc['es_incendio'].value_counts()
# Out:
# es_incendio
# 0    28405
# 1     6457
# Name: count, dtype: int64

# %% [markdown]
# Data consolidada procesada:

# %%
df_proc.head()
# Out:
#         time          y         x  es_incendio    id_incendio  fecha_ini  \
# 0 2017-03-10  6263970.0  278670.0            0  2016-2017-104 2017-03-12
# 1 2017-03-10  6336590.0  262030.0            0  2016-2017-104 2017-03-12
# 2 2017-03-10  6337090.0  262390.0            1  2016-2017-104 2017-03-12
# 3 2017-03-10  6336370.0  262090.0            0  2016-2017-104 2017-03-12
# 4 2017-03-10  6336490.0  262330.0            0  2016-2017-104 2017-03-12
#
#        tipo_dato  id_pixel    id_pixel_incendio  \
# 0    zona_random     13275  2016-2017-104-13275
# 1  zona_incendio      2083   2016-2017-104-2083
# 2  zona_incendio      2283   2016-2017-104-2283
# 3  zona_incendio      2314   2016-2017-104-2314
# 4  zona_incendio      2784   2016-2017-104-2784
#
#    d_areas_silvestres_protegidas  ...  dewpoint_temperature_2m_max_tmean  \
# 0                   25388.446707  ...                         284.911077
# 1                    4234.191694  ...                         285.841258
# 2                    4499.957523  ...                         285.841258
# 3                    4013.175417  ...                         285.841258
# 4                    3999.401165  ...                         285.841258
#
#    soil_temperature_level_1_max_tmean  total_precipitation_sum_tmean  \
# 0                          308.723872                       0.000120
# 1                          304.751867                       0.000001
# 2                          304.751867                       0.000001
# 3                          304.751867                       0.000001
# 4                          304.751867                       0.000001
#
#    u_component_of_wind_10m_tmean  u_component_of_wind_10m_max_tmean  \
# 0                       0.638061                           2.318019
# 1                       1.519517                           4.073023
# 2                       1.519517                           4.073023
# 3                       1.519517                           4.073023
# 4                       1.519517                           4.073023
#
#    u_component_of_wind_10m_min_tmean  v_component_of_wind_10m_tmean  \
# 0                          -1.062608                       0.103451
# 1                          -0.401321                       3.248165
# 2                          -0.401321                       3.248165
# 3                          -0.401321                       3.248165
# 4                          -0.401321                       3.248165
#
#    v_component_of_wind_10m_max_tmean  volumetric_soil_water_layer_1_tmean  \
# 0                           0.839816                             0.146767
# 1                           4.650551                             0.176087
# 2                           4.650551                             0.176087
# 3                           4.650551                             0.176087
# 4                           4.650551                             0.176087
#
#    volumetric_soil_water_layer_1_min_tmean
# 0                                 0.138229
# 1                                 0.175908
# 2                                 0.175908
# 3                                 0.175908
# 4                                 0.175908
#
# [5 rows x 39 columns]

# %% [markdown]
# Para reducir el desbalanceo seleccionaremos de forma aleatoria pixeles de clase no incendio

# %%
import random
random.seed(2024)
index = random.sample(df_proc[df_proc['es_incendio']==0].index.to_list(), 12914)

# %%
index
# Out:
# [19136,
#  7741,
#  30359,
#  23684,
#  12603,
#  8348,
#  30204,
#  17112,
#  31372,
#  29978,
#  31447,
#  10947,
#  21838,
#  10290,
#  26079,
#  33589,
#  30588,
#  20399,
#  14705,
#  17302,
#  21646,
#  30343,
#  25361,
#  8938,
#  12792,
#  22188,
#  29305,
#  13496,
#  21385,
#  3209,
#  30461,
#  32231,
#  8550,
#  28176,
#  31156,
#  30340,
#  19085,
#  29564,
#  34447,
#  26615,
#  6156,
#  21786,
#  8756,
#  17172,
#  2471,
#  32064,
#  14549,
#  25834,
#  17325,
#  18999,
#  5174,
#  30263,
#  30859,
#  5848,
#  31663,
#  13369,
#  16160,
#  13529,
#  14387,
#  32863,
#  8379,
#  13316,
#  17660,
#  17253,
#  13019,
#  23323,
#  8804,
#  17010,
#  9626,
#  8488,
#  1443,
#  31069,
#  9392,
#  31614,
#  637,
#  10739,
#  34871,
#  20823,
#  13110,
#  32156,
#  23405,
#  33214,
#  29366,
#  17471,
#  25254,
#  4439,
#  13550,
#  35119,
#  26622,
#  24873,
#  32428,
#  9719,
#  9992,
#  18946,
#  15083,
#  5754,
#  8442,
#  15184,
#  20120,
#  24272,
#  34614,
#  25815,
#  5928,
#  10840,
#  15937,
#  25669,
#  13921,
#  13824,
#  29542,
#  29785,
#  18968,
#  35455,
#  7024,
#  28007,
#  28385,
#  31912,
#  35454,
#  5619,
#  13601,
#  8568,
#  23775,
#  28089,
#  2780,
#  3978,
#  34858,
#  7261,
#  142,
#  6231,
#  18087,
#  29296,
#  9979,
#  14577,
#  9592,
#  3435,
#  8197,
#  33170,
#  11844,
#  10097,
#  28367,
#  18843,
#  24644,
#  10895,
#  19610,
#  21527,
#  17989,
#  27119,
#  17270,
#  8372,
#  34829,
#  3030,
#  12525,
#  12562,
#  11557,
#  5743,
#  23214,
#  27002,
#  30459,
#  10449,
#  35623,
#  4064,
#  20219,
#  8969,
#  8191,
#  32557,
#  16043,
#  7421,
#  21249,
#  35081,
#  9273,
#  13134,
#  14719,
#  31076,
#  29227,
#  33064,
#  1769,
#  23701,
#  27809,
#  22199,
#  15452,
#  30790,
#  30104,
#  25990,
#  3153,
#  4783,
#  9658,
#  2342,
#  21330,
#  5278,
#  34363,
#  8678,
#  26041,
#  25326,
#  3646,
#  20734,
#  35515,
#  9998,
#  19883,
#  23876,
#  33036,
#  30476,
#  6704,
#  6604,
#  3610,
#  5269,
#  25455,
#  4185,
#  33542,
#  24227,
#  23117,
#  33584,
#  24765,
#  25927,
#  989,
#  24269,
#  4305,
#  23060,
#  7674,
#  22203,
#  28992,
#  12963,
#  16,
#  5088,
#  11687,
#  948,
#  7758,
#  2610,
#  4169,
#  26053,
#  35325,
#  25710,
#  27608,
#  25545,
#  30554,
#  8675,
#  23711,
#  8600,
#  26354,
#  8016,
#  18836,
#  7887,
#  19231,
#  12928,
#  11260,
#  30501,
#  18603,
#  26018,
#  18120,
#  34550,
#  29956,
#  33262,
#  34095,
#  8910,
#  16788,
#  23959,
#  18435,
#  17385,
#  24234,
#  29254,
#  5678,
#  8653,
#  6550,
#  12862,
#  16713,
#  8241,
#  31158,
#  7652,
#  14787,
#  18651,
#  28091,
#  488,
#  4825,
#  13817,
#  27677,
#  96,
#  32172,
#  9252,
#  31141,
#  20895,
#  17412,
#  26839,
#  1287,
#  8808,
#  24981,
#  18957,
#  22774,
#  20291,
#  22301,
#  35388,
#  2038,
#  17816,
#  13609,
#  350,
#  21069,
#  14081,
#  22679,
#  10635,
#  27241,
#  30517,
#  6460,
#  9388,
#  24772,
#  4290,
#  34221,
#  32921,
#  34952,
#  17797,
#  2867,
#  5659,
#  7340,
#  829,
#  13972,
#  12724,
#  10528,
#  20206,
#  6583,
#  14991,
#  34482,
#  19011,
#  17891,
#  20054,
#  25238,
#  13344,
#  6538,
#  1271,
#  32044,
#  5002,
#  35366,
#  15008,
#  17624,
#  26096,
#  7706,
#  20805,
#  29359,
#  3888,
#  2280,
#  26898,
#  17971,
#  860,
#  33489,
#  11298,
#  9732,
#  4714,
#  13056,
#  22173,
#  23305,
#  5799,
#  8748,
#  23387,
#  23872,
#  4308,
#  17810,
#  4133,
#  24486,
#  29401,
#  35420,
#  10971,
#  17897,
#  23018,
#  6517,
#  31708,
#  9739,
#  1,
#  21218,
#  5193,
#  8302,
#  15481,
#  21909,
#  23506,
#  17009,
#  18335,
#  23497,
#  32695,
#  7215,
#  34369,
#  26359,
#  10360,
#  22601,
#  31780,
#  12211,
#  33703,
#  11450,
#  24134,
#  14793,
#  18473,
#  26122,
#  4417,
#  16927,
#  16721,
#  31559,
#  11714,
#  13077,
#  20569,
#  21474,
#  9572,
#  10057,
#  34037,
#  32402,
#  33241,
#  14832,
#  9501,
#  17476,
#  32704,
#  19049,
#  23502,
#  12762,
#  11956,
#  27716,
#  28047,
#  8140,
#  19079,
#  26372,
#  22093,
#  2253,
#  10521,
#  15570,
#  34253,
#  26570,
#  35377,
#  10870,
#  17226,
#  21339,
#  5705,
#  26611,
#  13015,
#  11881,
#  28141,
#  21991,
#  33246,
#  5693,
#  31731,
#  3818,
#  20803,
#  9073,
#  18921,
#  24920,
#  11699,
#  12370,
#  10363,
#  26463,
#  21356,
#  16099,
#  30707,
#  11725,
#  7810,
#  19508,
#  33313,
#  15053,
#  1019,
#  24436,
#  35261,
#  15391,
#  28375,
#  2723,
#  31292,
#  30177,
#  5676,
#  4089,
#  17552,
#  25185,
#  13260,
#  8039,
#  31886,
#  3261,
#  31432,
#  23693,
#  10588,
#  1075,
#  33277,
#  26207,
#  32230,
#  10824,
#  27482,
#  35020,
#  21424,
#  7992,
#  33088,
#  17900,
#  6880,
#  8096,
#  29854,
#  19208,
#  34202,
#  10979,
#  2953,
#  18869,
#  35591,
#  4052,
#  24192,
#  11036,
#  5564,
#  31061,
#  15784,
#  32517,
#  24058,
#  34415,
#  26368,
#  3975,
#  9224,
#  31257,
#  23878,
#  9938,
#  6680,
#  12330,
#  26530,
#  5807,
#  33786,
#  28343,
#  33333,
#  35137,
#  28094,
#  4298,
#  5580,
#  13997,
#  17187,
#  13418,
#  25868,
#  29140,
#  13698,
#  22294,
#  34076,
#  31135,
#  9984,
#  659,
#  24687,
#  11576,
#  15616,
#  5862,
#  23378,
#  11017,
#  7094,
#  20839,
#  35441,
#  10692,
#  8934,
#  22402,
#  5618,
#  29233,
#  17717,
#  30767,
#  22134,
#  8050,
#  5285,
#  33613,
#  5571,
#  27698,
#  28266,
#  9818,
#  10540,
#  817,
#  26141,
#  25407,
#  27806,
#  4357,
#  17559,
#  21772,
#  17450,
#  1104,
#  19308,
#  6400,
#  11479,
#  29790,
#  14880,
#  35400,
#  14486,
#  12189,
#  19617,
#  27783,
#  23793,
#  18407,
#  22625,
#  26417,
#  1031,
#  27911,
#  11819,
#  7922,
#  15645,
#  26567,
#  20238,
#  26133,
#  14936,
#  20673,
#  19805,
#  15019,
#  6476,
#  2743,
#  20937,
#  30641,
#  22564,
#  11041,
#  35373,
#  7756,
#  18136,
#  19022,
#  13345,
#  25591,
#  220,
#  5918,
#  30586,
#  4540,
#  17538,
#  2007,
#  11717,
#  31332,
#  26798,
#  30988,
#  3439,
#  29549,
#  3457,
#  27489,
#  19507,
#  18888,
#  8680,
#  21624,
#  20628,
#  27678,
#  31052,
#  34911,
#  9838,
#  27448,
#  26125,
#  27045,
#  12918,
#  26722,
#  21169,
#  26017,
#  12568,
#  19892,
#  12261,
#  23713,
#  2347,
#  27770,
#  8705,
#  27581,
#  30330,
#  22053,
#  19265,
#  29764,
#  10320,
#  12771,
#  26482,
#  12932,
#  10469,
#  13435,
#  1369,
#  5884,
#  25632,
#  21920,
#  32834,
#  22040,
#  10810,
#  14431,
#  14386,
#  6240,
#  2223,
#  14554,
#  499,
#  25580,
#  13005,
#  31092,
#  12976,
#  8202,
#  7925,
#  11807,
#  33290,
#  18609,
#  21759,
#  2045,
#  6524,
#  4034,
#  32610,
#  19674,
#  26156,
#  10888,
#  16424,
#  2250,
#  17189,
#  8342,
#  27888,
#  5656,
#  5696,
#  15004,
#  436,
#  18552,
#  14907,
#  35468,
#  17271,
#  10376,
#  5229,
#  14220,
#  25089,
#  18483,
#  13384,
#  228,
#  30607,
#  27607,
#  24278,
#  34356,
#  33296,
#  21440,
#  17233,
#  29906,
#  25779,
#  32248,
#  18213,
#  8422,
#  5415,
#  34585,
#  4596,
#  20993,
#  27860,
#  17074,
#  35479,
#  16656,
#  20302,
#  18570,
#  30326,
#  9126,
#  1684,
#  29026,
#  18439,
#  34736,
#  26920,
#  26205,
#  21587,
#  33787,
#  3251,
#  11038,
#  33289,
#  31591,
#  4661,
#  15214,
#  25818,
#  21914,
#  14937,
#  3000,
#  13374,
#  32828,
#  19707,
#  25012,
#  24184,
#  19311,
#  30991,
#  32406,
#  32762,
#  33205,
#  11337,
#  26307,
#  17016,
#  30220,
#  34128,
#  15394,
#  20531,
#  26223,
#  10689,
#  4433,
#  607,
#  10443,
#  21554,
#  29940,
#  29672,
#  17728,
#  6661,
#  31186,
#  6262,
#  7974,
#  481,
#  33141,
#  511,
#  11099,
#  2564,
#  4276,
#  13740,
#  6624,
#  9636,
#  10062,
#  21274,
#  11306,
#  32398,
#  3254,
#  6379,
#  34500,
#  1506,
#  10460,
#  33830,
#  14866,
#  3487,
#  21519,
#  15228,
#  23013,
#  7035,
#  4310,
#  14902,
#  10539,
#  32552,
#  421,
#  33339,
#  33530,
#  23629,
#  20954,
#  31480,
#  21989,
#  17867,
#  18323,
#  25585,
#  31163,
#  10212,
#  32493,
#  1183,
#  27752,
#  32102,
#  5944,
#  31680,
#  14643,
#  10985,
#  22284,
#  100,
#  18818,
#  10195,
#  15118,
#  18106,
#  2444,
#  6055,
#  8637,
#  13862,
#  2878,
#  24078,
#  32381,
#  5045,
#  18797,
#  3396,
#  32537,
#  30208,
#  3580,
#  9631,
#  95,
#  31359,
#  3395,
#  33953,
#  6591,
#  25864,
#  19028,
#  8669,
#  29161,
#  8275,
#  9756,
#  19166,
#  34319,
#  17063,
#  25605,
#  23771,
#  3334,
#  32050,
#  26656,
#  17359,
#  31437,
#  21669,
#  31152,
#  15681,
#  21478,
#  10981,
#  34086,
#  33936,
#  25967,
#  29908,
#  29438,
#  5997,
#  10202,
#  14930,
#  30798,
#  8207,
#  6378,
#  19512,
#  653,
#  35182,
#  30265,
#  5512,
#  11404,
#  17193,
#  27855,
#  34545,
#  10104,
#  27966,
#  17983,
#  16742,
#  34349,
#  27898,
#  6463,
#  15801,
#  15438,
#  18306,
#  23468,
#  26105,
#  4754,
#  30338,
#  11107,
#  22159,
#  10834,
#  25311,
#  6113,
#  13331,
#  4711,
#  25909,
#  27266,
#  34747,
#  3432,
#  14461,
#  20135,
#  5073,
#  23759,
#  8066,
#  35086,
#  21475,
#  5898,
#  33308,
#  18817,
#  4217,
#  24905,
#  24800,
#  16749,
#  18973,
#  30108,
#  31880,
#  23205,
#  23479,
#  17099,
#  30584,
#  18075,
#  19840,
#  13218,
#  23512,
#  13131,
#  25348,
#  21540,
#  10045,
#  7226,
#  9206,
#  25246,
#  34879,
#  17236,
#  889,
#  21057,
#  18806,
#  30857,
#  21205,
#  15106,
#  1694,
#  12664,
#  30849,
#  6630,
#  28206,
#  23636,
#  11316,
#  9714,
#  9023,
#  23343,
#  26396,
#  27951,
#  23624,
#  18031,
#  25787,
#  32637,
#  32882,
#  18845,
#  14385,
#  21386,
#  29006,
#  3592,
#  18789,
#  26747,
#  21485,
#  12496,
#  13900,
#  539,
#  25461,
#  35493,
#  31037,
#  19365,
#  8444,
#  26317,
#  11754,
#  34684,
#  17670,
#  34667,
#  3499,
#  6069,
#  19661,
#  26584,
#  23017,
#  17393,
#  12470,
#  11104,
#  20629,
#  30079,
#  14183,
#  32544,
#  3748,
#  6318,
#  7967,
#  3488,
#  22076,
#  ...]

# %%
df_proc_new = pd.concat([df_proc.loc[index], df_proc[df_proc['es_incendio']==1]], axis =0)

# %%
df_proc_new['es_incendio'].value_counts()
# Out:
# es_incendio
# 0    12914
# 1     6457
# Name: count, dtype: int64

# %%
#df_proc[['d_areas_silvestres_protegidas', 'd_red_hidrografica', 'd_areas_urbanas','d_red_vial']] = df_proc[['d_areas_silvestres_protegidas', 'd_red_hidrografica', 'd_areas_urbanas','d_red_vial']].round(4)

# %% [markdown]
# #### Separación y obtencion de scaler

# %% [markdown]
# Realizamos separación train-test según incendios, para ello dejaremos como testeo el ultimo año con incendios:

# %%
df_proc_new['id_incendio'].value_counts()
# Out:
# id_incendio
# 2018-2019-62     1296
# 2020-2021-11     1285
# 2018-2019-63     1279
# 2020-2021-1      1272
# 2018-2019-64     1271
# 2018-2019-0      1246
# 2022-2023-2      1231
# 2021-2022-5      1225
# 2020-2021-0      1224
# 2021-2022-4      1216
# 2022-2023-0      1211
# 2022-2023-3      1192
# 2016-2017-104    1185
# 2021-2022-3      1129
# 2022-2023-4      1116
# 2022-2023-1       964
# 2016-2017-136      20
# 2016-2017-87        9
# Name: count, dtype: int64

# %%
df_proc_new['agno_inicio_incendio'] = [item.split("-", 1)[0] for item in df_proc_new['id_incendio']]

# %%
agno_incendios = list(set([item.split("-", 1)[0] for item in df_proc_new['id_incendio'].unique()]))
agno_incendios.sort()
ultimo_agno = agno_incendios[-1]  # testeo 2022

filtro_agno = df_proc_new['agno_inicio_incendio'].apply(lambda x: ultimo_agno in x)

# %%
X_test = df_proc_new[filtro_agno]
X_train = df_proc_new[-filtro_agno]
X_train
# Out:
#             time          y         x  es_incendio   id_incendio  fecha_ini  \
# 19136 2022-02-22  6344570.0  394890.0            0   2021-2022-3 2022-02-23
# 7741  2019-01-24  6348930.0  284270.0            0  2018-2019-63 2019-01-26
# 23684 2022-02-27  6350150.0  364350.0            0   2021-2022-5 2022-02-28
# 12603 2021-01-13  6438330.0  359850.0            0   2020-2021-0 2021-01-15
# 8348  2019-01-24  6351990.0  273490.0            0  2018-2019-63 2019-01-26
# ...          ...        ...       ...          ...           ...        ...
# 24525 2022-02-27  6335950.0  261590.0            1   2021-2022-5 2022-02-28
# 24528 2022-02-27  6334250.0  261990.0            1   2021-2022-5 2022-02-28
# 24529 2022-02-27  6336130.0  260630.0            1   2021-2022-5 2022-02-28
# 24532 2022-02-27  6335370.0  262010.0            1   2021-2022-5 2022-02-28
# 24534 2022-02-27  6334510.0  261730.0            1   2021-2022-5 2022-02-28
#
#            tipo_dato  id_pixel   id_pixel_incendio  \
# 19136    zona_random     24494   2021-2022-3-24494
# 7741     zona_random     40896  2018-2019-63-40896
# 23684    zona_random     26549   2021-2022-5-26549
# 12603    zona_random     49994   2020-2021-0-49994
# 8348     zona_random     41503  2018-2019-63-41503
# ...              ...       ...                 ...
# 24525  zona_incendio      2892    2021-2022-5-2892
# 24528  zona_incendio      2895    2021-2022-5-2895
# 24529  zona_incendio      2896    2021-2022-5-2896
# 24532  zona_incendio      2899    2021-2022-5-2899
# 24534  zona_incendio      2901    2021-2022-5-2901
#
#        d_areas_silvestres_protegidas  ...  soil_temperature_level_1_max_tmean  \
# 19136                   82869.594612  ...                          306.171655
# 7741                    15517.009100  ...                          295.869400
# 23684                   52015.514424  ...                          302.288300
# 12603                   98063.880346  ...                          312.735104
# 8348                    18676.148471  ...                          310.544510
# ...                              ...  ...                                 ...
# 24525                    3893.922330  ...                          303.527557
# 24528                    2254.794164  ...                          303.527557
# 24529                    4572.249919  ...                          303.527557
# 24532                    3182.287612  ...                          303.527557
# 24534                    2621.264701  ...                          303.527557
#
#        total_precipitation_sum_tmean  u_component_of_wind_10m_tmean  \
# 19136                       0.000003                       1.477213
# 7741                        0.002344                       0.684187
# 23684                       0.000830                       1.023560
# 12603                       0.000014                       1.205887
# 8348                        0.000011                       1.248803
# ...                              ...                            ...
# 24525                       0.000001                       1.667908
# 24528                       0.000001                       1.667908
# 24529                       0.000001                       1.667908
# 24532                       0.000001                       1.667908
# 24534                       0.000001                       1.667908
#
#        u_component_of_wind_10m_max_tmean  u_component_of_wind_10m_min_tmean  \
# 19136                           3.541275                          -0.011783
# 7741                            2.511160                          -0.858508
# 23684                           3.349281                          -0.684174
# 12603                           2.550864                          -0.148400
# 8348                            2.761453                           0.088299
# ...                                  ...                                ...
# 24525                           4.514786                          -0.063469
# 24528                           4.514786                          -0.063469
# 24529                           4.514786                          -0.063469
# 24532                           4.514786                          -0.063469
# 24534                           4.514786                          -0.063469
#
#        v_component_of_wind_10m_tmean  v_component_of_wind_10m_max_tmean  \
# 19136                       0.327348                           1.548809
# 7741                       -0.252011                           0.070113
# 23684                      -0.463304                           0.195862
# 12603                       0.407744                           0.924523
# 8348                        0.301786                           0.796311
# ...                              ...                                ...
# 24525                       2.892419                           4.671333
# 24528                       2.892419                           4.671333
# 24529                       2.892419                           4.671333
# 24532                       2.892419                           4.671333
# 24534                       2.892419                           4.671333
#
#        volumetric_soil_water_layer_1_tmean  \
# 19136                             0.251515
# 7741                              0.178315
# 23684                             0.050770
# 12603                             0.148351
# 8348                              0.251289
# ...                                    ...
# 24525                             0.119444
# 24528                             0.119444
# 24529                             0.119444
# 24532                             0.119444
# 24534                             0.119444
#
#        volumetric_soil_water_layer_1_min_tmean  agno_inicio_incendio
# 19136                                 0.251434                  2021
# 7741                                  0.157669                  2018
# 23684                                 0.043297                  2021
# 12603                                 0.148197                  2020
# 8348                                  0.251183                  2018
# ...                                        ...                   ...
# 24525                                 0.119370                  2021
# 24528                                 0.119370                  2021
# 24529                                 0.119370                  2021
# 24532                                 0.119370                  2021
# 24534                                 0.119370                  2021
#
# [13657 rows x 40 columns]

# %%
X_train['es_incendio'].value_counts()
# Out:
# es_incendio
# 0    8913
# 1    4744
# Name: count, dtype: int64

# %%
X_test['es_incendio'].value_counts()
# Out:
# es_incendio
# 0    4001
# 1    1713
# Name: count, dtype: int64

# %%
y_train = X_train['es_incendio']
y_test = X_test['es_incendio']

X_train = X_train.drop(['es_incendio', 'agno_inicio_incendio'], axis= 1)
X_test = X_test.drop(['es_incendio', 'agno_inicio_incendio'], axis= 1)

# %%
num_train = X_train.drop(['id_pixel', 'id_incendio', 'x', 'y', 'tipo_dato', 'fecha_ini', 'time', 'id_pixel_incendio'], axis = 1)
num_test = X_test.drop(['id_pixel', 'id_incendio', 'x', 'y', 'tipo_dato', 'fecha_ini', 'time', 'id_pixel_incendio'], axis = 1)

elim_row = -np.isinf(num_train.evi_tmean)
num_train = num_train[elim_row]   # existe una observacion con valores inf 

y_train = y_train[elim_row]

# %% [markdown]
# Realizando estandarización de datos:

# %%
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(num_train)
X_test_scaled = scaler.transform(num_test)

X_train_scaled_df = num_train
X_test_scaled_df = num_test

# %% [markdown]
# #### Comparando modelos de clasificación

# %%
## settings
clf = setup(data= pd.concat([X_train_scaled_df, y_train], axis =1), target='es_incendio', session_id= 2024)

best_model = compare_models(sort='F1')
final_model = finalize_model(best_model)
final_model
# Out:
# <style type="text/css">
# #T_6bd91_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6bd91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bd91_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_6bd91_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bd91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bd91_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_6bd91_row0_col1" class="data row0 col1" >2024</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6bd91_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6bd91_row1_col1" class="data row1 col1" >es_incendio</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6bd91_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_6bd91_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6bd91_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_6bd91_row3_col1" class="data row3 col1" >(13656, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6bd91_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_6bd91_row4_col1" class="data row4 col1" >(13656, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6bd91_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_6bd91_row5_col1" class="data row5 col1" >(9559, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6bd91_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_6bd91_row6_col1" class="data row6 col1" >(4097, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6bd91_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_6bd91_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6bd91_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_6bd91_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6bd91_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_6bd91_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6bd91_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_6bd91_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6bd91_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_6bd91_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6bd91_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_6bd91_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6bd91_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_6bd91_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6bd91_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_6bd91_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6bd91_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_6bd91_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6bd91_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_6bd91_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6bd91_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_6bd91_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6bd91_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6bd91_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_6bd91_row18_col1" class="data row18 col1" >d44b</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_ba6d4 th {
#   text-align: left;
# }
# #T_ba6d4_row0_col0, #T_ba6d4_row0_col1, #T_ba6d4_row0_col3, #T_ba6d4_row0_col4, #T_ba6d4_row1_col0, #T_ba6d4_row1_col2, #T_ba6d4_row1_col3, #T_ba6d4_row1_col5, #T_ba6d4_row1_col6, #T_ba6d4_row1_col7, #T_ba6d4_row2_col0, #T_ba6d4_row2_col1, #T_ba6d4_row2_col2, #T_ba6d4_row2_col3, #T_ba6d4_row2_col4, #T_ba6d4_row2_col5, #T_ba6d4_row2_col6, #T_ba6d4_row2_col7, #T_ba6d4_row3_col0, #T_ba6d4_row3_col1, #T_ba6d4_row3_col2, #T_ba6d4_row3_col3, #T_ba6d4_row3_col4, #T_ba6d4_row3_col5, #T_ba6d4_row3_col6, #T_ba6d4_row3_col7, #T_ba6d4_row4_col0, #T_ba6d4_row4_col1, #T_ba6d4_row4_col2, #T_ba6d4_row4_col3, #T_ba6d4_row4_col4, #T_ba6d4_row4_col5, #T_ba6d4_row4_col6, #T_ba6d4_row4_col7, #T_ba6d4_row5_col0, #T_ba6d4_row5_col1, #T_ba6d4_row5_col2, #T_ba6d4_row5_col3, #T_ba6d4_row5_col4, #T_ba6d4_row5_col5, #T_ba6d4_row5_col6, #T_ba6d4_row5_col7, #T_ba6d4_row6_col0, #T_ba6d4_row6_col1, #T_ba6d4_row6_col2, #T_ba6d4_row6_col3, #T_ba6d4_row6_col4, #T_ba6d4_row6_col5, #T_ba6d4_row6_col6, #T_ba6d4_row6_col7, #T_ba6d4_row7_col0, #T_ba6d4_row7_col1, #T_ba6d4_row7_col2, #T_ba6d4_row7_col4, #T_ba6d4_row7_col5, #T_ba6d4_row7_col6, #T_ba6d4_row7_col7, #T_ba6d4_row8_col0, #T_ba6d4_row8_col1, #T_ba6d4_row8_col2, #T_ba6d4_row8_col3, #T_ba6d4_row8_col4, #T_ba6d4_row8_col5, #T_ba6d4_row8_col6, #T_ba6d4_row8_col7, #T_ba6d4_row9_col0, #T_ba6d4_row9_col1, #T_ba6d4_row9_col2, #T_ba6d4_row9_col3, #T_ba6d4_row9_col4, #T_ba6d4_row9_col5, #T_ba6d4_row9_col6, #T_ba6d4_row9_col7, #T_ba6d4_row10_col0, #T_ba6d4_row10_col1, #T_ba6d4_row10_col2, #T_ba6d4_row10_col3, #T_ba6d4_row10_col4, #T_ba6d4_row10_col5, #T_ba6d4_row10_col6, #T_ba6d4_row10_col7, #T_ba6d4_row11_col0, #T_ba6d4_row11_col1, #T_ba6d4_row11_col2, #T_ba6d4_row11_col3, #T_ba6d4_row11_col4, #T_ba6d4_row11_col5, #T_ba6d4_row11_col6, #T_ba6d4_row11_col7, #T_ba6d4_row12_col0, #T_ba6d4_row12_col1, #T_ba6d4_row12_col2, #T_ba6d4_row12_col3, #T_ba6d4_row12_col4, #T_ba6d4_row12_col5, #T_ba6d4_row12_col6, #T_ba6d4_row12_col7, #T_ba6d4_row13_col0, #T_ba6d4_row13_col1, #T_ba6d4_row13_col2, #T_ba6d4_row13_col3, #T_ba6d4_row13_col4, #T_ba6d4_row13_col5, #T_ba6d4_row13_col6, #T_ba6d4_row13_col7, #T_ba6d4_row14_col0, #T_ba6d4_row14_col1, #T_ba6d4_row14_col2, #T_ba6d4_row14_col3, #T_ba6d4_row14_col4, #T_ba6d4_row14_col5, #T_ba6d4_row14_col6, #T_ba6d4_row14_col7 {
#   text-align: left;
# }
# #T_ba6d4_row0_col2, #T_ba6d4_row0_col5, #T_ba6d4_row0_col6, #T_ba6d4_row0_col7, #T_ba6d4_row1_col1, #T_ba6d4_row1_col4, #T_ba6d4_row7_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ba6d4_row0_col8, #T_ba6d4_row1_col8, #T_ba6d4_row2_col8, #T_ba6d4_row3_col8, #T_ba6d4_row4_col8, #T_ba6d4_row5_col8, #T_ba6d4_row6_col8, #T_ba6d4_row7_col8, #T_ba6d4_row8_col8, #T_ba6d4_row9_col8, #T_ba6d4_row10_col8, #T_ba6d4_row11_col8, #T_ba6d4_row12_col8, #T_ba6d4_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ba6d4_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ba6d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba6d4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ba6d4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ba6d4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ba6d4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ba6d4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ba6d4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ba6d4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ba6d4_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ba6d4_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba6d4_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_ba6d4_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_ba6d4_row0_col1" class="data row0 col1" >0.8889</td>
#       <td id="T_ba6d4_row0_col2" class="data row0 col2" >0.9561</td>
#       <td id="T_ba6d4_row0_col3" class="data row0 col3" >0.8847</td>
#       <td id="T_ba6d4_row0_col4" class="data row0 col4" >0.8125</td>
#       <td id="T_ba6d4_row0_col5" class="data row0 col5" >0.8469</td>
#       <td id="T_ba6d4_row0_col6" class="data row0 col6" >0.7600</td>
#       <td id="T_ba6d4_row0_col7" class="data row0 col7" >0.7618</td>
#       <td id="T_ba6d4_row0_col8" class="data row0 col8" >0.1630</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d4_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_ba6d4_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_ba6d4_row1_col1" class="data row1 col1" >0.8894</td>
#       <td id="T_ba6d4_row1_col2" class="data row1 col2" >0.9551</td>
#       <td id="T_ba6d4_row1_col3" class="data row1 col3" >0.8717</td>
#       <td id="T_ba6d4_row1_col4" class="data row1 col4" >0.8213</td>
#       <td id="T_ba6d4_row1_col5" class="data row1 col5" >0.8456</td>
#       <td id="T_ba6d4_row1_col6" class="data row1 col6" >0.7596</td>
#       <td id="T_ba6d4_row1_col7" class="data row1 col7" >0.7606</td>
#       <td id="T_ba6d4_row1_col8" class="data row1 col8" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d4_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_ba6d4_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_ba6d4_row2_col1" class="data row2 col1" >0.8870</td>
#       <td id="T_ba6d4_row2_col2" class="data row2 col2" >0.9544</td>
#       <td id="T_ba6d4_row2_col3" class="data row2 col3" >0.8778</td>
#       <td id="T_ba6d4_row2_col4" class="data row2 col4" >0.8126</td>
#       <td id="T_ba6d4_row2_col5" class="data row2 col5" >0.8437</td>
#       <td id="T_ba6d4_row2_col6" class="data row2 col6" >0.7555</td>
#       <td id="T_ba6d4_row2_col7" class="data row2 col7" >0.7571</td>
#       <td id="T_ba6d4_row2_col8" class="data row2 col8" >0.3520</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d4_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_ba6d4_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#       <td id="T_ba6d4_row3_col1" class="data row3 col1" >0.8802</td>
#       <td id="T_ba6d4_row3_col2" class="data row3 col2" >0.9497</td>
#       <td id="T_ba6d4_row3_col3" class="data row3 col3" >0.8847</td>
#       <td id="T_ba6d4_row3_col4" class="data row3 col4" >0.7945</td>
#       <td id="T_ba6d4_row3_col5" class="data row3 col5" >0.8369</td>
#       <td id="T_ba6d4_row3_col6" class="data row3 col6" >0.7427</td>
#       <td id="T_ba6d4_row3_col7" class="data row3 col7" >0.7457</td>
#       <td id="T_ba6d4_row3_col8" class="data row3 col8" >0.1760</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d4_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_ba6d4_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ba6d4_row4_col1" class="data row4 col1" >0.8610</td>
#       <td id="T_ba6d4_row4_col2" class="data row4 col2" >0.9373</td>
#       <td id="T_ba6d4_row4_col3" class="data row4 col3" >0.8675</td>
#       <td id="T_ba6d4_row4_col4" class="data row4 col4" >0.7644</td>
#       <td id="T_ba6d4_row4_col5" class="data row4 col5" >0.8125</td>
#       <td id="T_ba6d4_row4_col6" class="data row4 col6" >0.7028</td>
#       <td id="T_ba6d4_row4_col7" class="data row4 col7" >0.7065</td>
#       <td id="T_ba6d4_row4_col8" class="data row4 col8" >1.0190</td>
#     </tr>
#     <tr>
#       <th id="T_ba6d4_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_ba6d4_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_ba6d4_row5_col1" class="data row5 col1" >0.8551</td>
#       <td id="T_ba6d4_row5_col2" class="data row5 col2" >0.8411</td>
#       <td id="T_ba6d4_row5_col3" class="data row5 col3" >0.7952</td>
#       <td id="T_ba6d4_row5_col4" class="data row5 col4" >0.7895</td>
#       <td
# Pipeline(memory=Memory(location=None),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['d_areas_silvestres_protegidas',
#                                              'd_red_vial', 'ndvi_t', 'evi_t',
#                                              'ndwi_t',
#                                              'dewpoint_temperature_2m_t',
#                                              'dewpoint_temperature_2m_max_t',
#                                              'soil_temperature_level_1_max_t',
#                                              'total_precipitation_sum_t',
#                                              'u_component_of_wind_10m_t',
#                                              'u_component_of_wind_10...
#                  LGBMClassifier(boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, importance_type='split',
#                                 learning_rate=0.1, max_depth=-1,
#                                 min_child_samples=20, min_child_weight=0.001,
#                                 min_split_gain=0.0, n_estimators=100, n_jobs=-1,
#                                 num_leaves=31, objective=None,
#                                 random_state=2024, reg_alpha=0.0,
#                                 reg_lambda=0.0, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0))],
#          verbose=False)

# %% [markdown]
# #### Ajustando XGBoost

# %%
xgb_model = xgb.XGBClassifier(
    max_depth = 2,
    learning_rate = 0.1,
    n_estimators = 10,
    verbosity = 1,
    objective = 'binary:logistic',
    booster = 'gbtree',
    n_jobs = -1,
    random_state = 2024
    #,reg_alpha = 20
    #,reg_lambda = 5
)

# %%
xgb_model.fit(X_train_scaled_df, y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=2, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=10, n_jobs=-1,
#               num_parallel_tree=None, objective='binary:logistic', ...)

# %% [markdown]
# Revisando metricas

# %%
y_pred = xgb_model.predict(X_test_scaled_df)

reporte = classification_report(y_test, y_pred, output_dict=True)
pd.DataFrame(reporte).transpose().to_csv('metricas.csv')

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79      4001
#            1       0.46      0.36      0.40      1713
#
#     accuracy                           0.68      5714
#    macro avg       0.61      0.59      0.59      5714
# weighted avg       0.66      0.68      0.67      5714

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[3299,  702],
#        [1103,  610]], dtype=int64)

# %%
# Matriz de confusión
import seaborn as sns
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False, cmap = 'Blues')
plt.xlabel('Valor real')
plt.ylabel('Predicción etiqueta');

# %%
pred_proba= xgb_model.predict_proba(X_test_scaled_df)

# %%
plot_importance(xgb_model, )
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# Calculando shap values

# %%
explainer = shap.Explainer(xgb_model, X_train_scaled_df)

shap_values = explainer.shap_values(X_test_scaled_df)

# primer valor set testeo
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values[0,:], X_test_scaled_df.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iCK7Y9E4VVZ1IAONG5OB1'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.7237468031638994, "outValue": -1.934318580835475, "link": "identity", "featureNames": ["d_areas_silvestres_protegidas", "d_red_vial", "ndvi_t", "evi_t", "ndwi_t", "dewpoint_temperature_2m_t", "dewpoint_temperature_2m_max_t", "soil_temperature_level_1_max_t", "total_precipitation_sum_t", "u_component_of_wind_10m_t", "u_component_of_wind_10m_max_t", "u_component_of_wind_10m_min_t", "v_component_of_wind_10m_t", "v_component_of_wind_10m_max_t", "volumetric_soil_water_layer_1_t", "volumetric_soil_water_layer_1_min_t", "ndvi_tmean", "evi_tmean", "ndwi_tmean", "dewpoint_temperature_2m_tmean", "dewpoint_temperature_2m_max_tmean", "soil_temperature_level_1_max_tmean", "total_precipitation_sum_tmean", "u_component_of_wind_10m_tmean", "u_component_of_wind_10m_max_tmean", "u_component_of_wind_10m_min_tmean", "v_component_of_wind_10m_tmean", "v_component_of_wind_10m_max_tmean", "volumetric_soil_water_layer_1_tmean", "volumetric_soil_water_layer_1_min_tmean"], "features": {"0": {"effect": -0.7204823435842991, "value": 54629.02725493487}, "2": {"effect": 0.027896695733070374, "value": 0.3051907442151345}, "5": {"effect": 0.03532591089606285, "value": 282.3116391499837}, "15": {"effect": -0.015919682383537293, "value": 0.144744873046875}, "21": {"effect": -0.10615808010101319, "value": 312.87440999348956}, "24": {"effect": -0.3828904044628143, "value": 2.5142386754353843}, "28": {"effect": -0.04834387376904488, "value": 0.14516745673285586}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iCK7Y9E4VVZ1IAONG5OB1')
#   );
# </script>

# %%
shap.summary_plot(shap_values, X_test_scaled_df)

# %% [markdown]
# #### VIZ

# %%
prob_pos = pred_proba[:, 1]

# %%
X_test.time.value_counts()
# Out:
# time
# 2022-12-14    2442
# 2022-12-19    1192
# 2022-11-19    1116
# 2023-05-08     964
# Name: count, dtype: int64

# %%
X_test['prob'] = prob_pos
X_test['y_test'] = y_test

# %%
rev_dia = X_test[X_test['time']== '2022-12-19']

# %%
min_prob = min(prob_pos.min(), y_test.min())
max_prob = max(prob_pos.max(), y_test.max())

norm = Normalize(vmin=min_prob, vmax=max_prob)

plt.figure(figsize=(15, 5))


# Subgráfico 2: XGB
plt.subplot(1, 3, 2)
plt.scatter(rev_dia.x, rev_dia.y, c=rev_dia.prob, cmap='viridis', norm=norm, marker='s', s=50, alpha=0.7)
plt.colorbar(label='Probabilidad')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.title('Mapa de Calor de Probabilidades XGBOOST')
plt.grid(True)

# Subgráfico 3: REAL
plt.subplot(1, 3, 3)
plt.scatter(rev_dia.x, rev_dia.y, c=rev_dia.y_test, cmap='viridis', norm=norm, marker='s', s=50, alpha=0.5)
plt.colorbar(label='Probabilidad')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.title('Mapa de Calor REAL')
plt.grid(True)

# Ajustar el espacio entre los subgráficos para evitar superposiciones
plt.tight_layout()

# Mostrar los subgráficos
plt.show()

# %% [markdown]
# Guardando predicciones:

# %%
X_test['pred_XGB'] = prob_pos
X_test['es_incedio']= y_test
X_test.to_csv('predicciones_test.csv')

# %% [markdown]
# Guardando modelo:

# %%
import joblib
joblib.dump(xgb_model, 'xgb_model_v1.pkl')


X_train['es_incedio'] = y_train
aux = {'X_train': X_train , 'X_test': X_test, 'scaler': scaler}
joblib.dump(aux, 'train_test_scaler.pkl')
# Out:
# ['train_test_scaler.pkl']
